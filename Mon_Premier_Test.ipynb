# %% [markdown]
# <a href="https://colab.research.google.com/github/mouad-21/PROJET_DEEPCHECK/blob/main/Mon_Premier_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

# Connexion au Drive
drive.mount('/content/drive')

# Définition du chemin (vérifie bien le nom de ton ZIP dans ton Drive)
zip_path = "/content/drive/My Drive/PROJET_DEEPCHECK/archive.zip"
extract_path = "/content/drive/My Drive/PROJET_DEEPCHECK/archive"

# Dézippage (à ne faire qu'une seule fois)
if not os.path.exists(extract_path):
    # !unzip -q "{zip_path}" -d "{extract_path}"
    print("Dézippage terminé !")
else:
    print("Les données sont déjà extraites.")
